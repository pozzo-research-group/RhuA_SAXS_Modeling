# %%
import numpy as np
import pandas as pd
import sys
import os
sys.path.append('../')
from genetic_algorithm import GA_functions as GA
#sys.path.append('../../SAXS/sasview/src')
#from sasmodels.data import load_data
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
import scipy

# %% [markdown]
# ## Load Data

# %%
filenames = os.listdir('../Data/Simulated_Scattering_Data/')

# %%
filenames
# Out:
# ['SAXS_RhuA_82.npy',
#  'SAXS_RhuA_82_Assembly_13_40OD_30ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_15_44OD_34ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_17_48OD_38ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_19_52OD_42ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_21_58OD_48ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_23_66OD_56ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_25_70OD_60ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_27_74OD_64ID_1200long.npy',
#  'SAXS_RhuA_82_Assembly_29_78OD_68ID_1200long.npy']

# %%
model0 = np.load('../Data/Simulated_Scattering_Data/' + filenames[0])
model1 = np.load('../Data/Simulated_Scattering_Data/' + filenames[1])
model2 = np.load('../Data/Simulated_Scattering_Data/' + filenames[2])
model3 = np.load('../Data/Simulated_Scattering_Data/' + filenames[3])
model4 = np.load('../Data/Simulated_Scattering_Data/' + filenames[4])
model5 = np.load('../Data/Simulated_Scattering_Data/' + filenames[5])
model6 = np.load('../Data/Simulated_Scattering_Data/' + filenames[6])
model7 = np.load('../Data/Simulated_Scattering_Data/' + filenames[7])
model8 = np.load('../Data/Simulated_Scattering_Data/' + filenames[8])
model9 = np.load('../Data/Simulated_Scattering_Data/' + filenames[9])
data = np.load('../Data/Experimental_Scattering_Data/Tubes_Exp_Data.npy')

# %%
plt.subplots(figsize=(9,9))
#plt.loglog(data1.x[:-120], data1.y[:-120], label = 'Old Data')
plt.loglog(data[:,0], data[:,1]*6*10e-2, label = 'Experimental SAXS Data')
#plt.loglog(data2[:,0], data2[:,1]*6*10e-2, label = 'Aged Sample KCl (JSP Stage)')
plt.ylabel('Intensity (A.U.)')
plt.xlabel('q ($\AA^{-1}$)')
plt.legend()

# %%
plt.rcParams.update({'font.size': 36})
plt.subplots(figsize=(9,9))
background = 9*10e-6
scale = 0.1
plt.loglog(model0[:,0], model0[:,1], linewidth = 5, alpha = 0.75, label = 'Monomer')
plt.loglog(model2[:,0], model2[:,1], linewidth = 5, alpha = 0.75, label = '27-start')
plt.loglog(model3[:,0], model3[:,1], linewidth = 5, alpha = 0.75, label = '25-start')
plt.loglog(model4[:,0], model4[:,1], linewidth = 5, alpha = 0.75, label = '23-start')
plt.loglog(model5[:,0], model5[:,1], linewidth = 5, alpha = 0.75, label = '21-start')
plt.loglog(model6[:,0], model6[:,1], linewidth = 5, alpha = 0.75, label = '19-start')
plt.loglog(model7[:,0], model7[:,1], linewidth = 5, alpha = 0.75, label = '17-start')

#plt.ylim([3*10**-2, 3*10**-1])
#plt.xlim([0.003, 0.15])
#plt.legend()
plt.ylabel('Intensity (A.U.)')
plt.xlabel('q ($\AA^{-1}$)')
plt.legend(fontsize=16)
#plt.savefig('../Figures/Fitting/models_curve_big_legend.jpg', dpi=600, bbox_inches="tight")

# %% [markdown]
# ## Use GA to Fit Data

# %%
#Convert model to length of data 
def convert_data(data, model):
    model_x = model[:,0]
    model_y = model[:,1]
    index = np.linspace(0, len(model_x)-1, len(model_x)) 
    model_q_new = []
    model_I_new = []
    for i in range(len(data)):
        data_q = data[i,0]
        array = np.abs(model_x - data_q)
        array = np.hstack((array.reshape(-1,1), index.reshape(-1,1)))
        array = array[np.argsort(array[:, 0])]
        loc = int(array[0,1])
        model_q_new.append(model_x[loc])
        model_I_new.append(model_y[loc])
    q = np.array(model_q_new).reshape(-1,1)
    I = np.array(model_I_new).reshape(-1,1)
    new_model_data = np.hstack((q, I))
    return new_model_data

# %%
# # Use for experimental data as txt file
# datax = data3.x[5:-500].reshape(-1,1)
# datay = data3.y[5:-500].reshape(-1,1)
# data = np.hstack((datax, datay))

# %%
# Use for experimental data as numpy file
#data = data2[3:-25, 0:2]

# %%
#Convert model to have the same size as data
model_0 = convert_data(data, model0)
model_1 = convert_data(data, model1)
model_2 = convert_data(data, model2)
model_3 = convert_data(data, model3)
model_4 = convert_data(data, model4)
model_5 = convert_data(data, model5)
model_6 = convert_data(data, model6)
model_7 = convert_data(data, model7)
model_8 = convert_data(data, model8)
model_9 = convert_data(data, model9)

# %%
#Normalize Data
# model_0[:,1] = model_0[:,1]/np.max(model_0[:,1])
# model_1[:,1] = model_1[:,1]/np.max(model_1[:,1])
# model_2[:,1] = model_2[:,1]/np.max(model_2[:,1])
# model_3[:,1] = model_3[:,1]/np.max(model_3[:,1])
# model_4[:,1] = model_4[:,1]/np.max(model_4[:,1])
# model_5[:,1] = model_5[:,1]/np.max(model_5[:,1])
# model_6[:,1] = model_6[:,1]/np.max(model_6[:,1])
# data[:,1] = data[:,1]/np.max(data[:,1])

# %%
def func(w0, w1, w2, w3, w4, w5, w6, w7, w8, w9, scale): #This will be our objective function 
    model_avg = (w0*model_0[:,1]*1000 + w1*model_1[:,1] + w2*model_2[:,1] + w3*model_3[:,1] + w4*model_4[:,1] + w5*model_5[:,1] + w6*model_6[:,1] + w7*model_7[:,1] + w8*model_8[:,1] + w9*model_9[:,1])
    background = 2.5*10e-4
    error = np.mean(np.abs(np.log10(data_y*((scale + 10e-10)*10e8) - background) - np.log10(model_avg)))
    return -error

def func_loop(x):
    for i in range(x.shape[0]): # This is a loop that runs the test function for each row of an array
        y_row = func(x[i,0], x[i,1], x[i,2], x[i,3], x[i,4], x[i,5], x[i,6], x[i,7], x[i,8], x[i,9], x[i,10]).reshape(1,-1)
        if i == 0:
            y = y_row
        else:
            y = np.vstack((y, y_row))
    return y

def overall_max(scores): # This creates a list of the cumulative best scores from the scores in a list
    all_max = [scores[0]]
    for i in range(len(scores)):
        if scores[i] > all_max[i]:
            all_max.append(scores[i])
        else:
            all_max.append(all_max[i])
    return all_max

def invariant(data):
    q = data[:,0]
    I = data[:,1]
    invariant = scipy.integrate.simps(q**2*I, q)
    return invariant

# %%
data_y = data[:,1]
batch_size = 500
x = np.random.rand(batch_size,11)
y = func_loop(x)

# %%
mutation_rate = 0.2
alg = GA.genetic_algorithm(batch_size, mutation_rate)

# %%
iterations = 500
for i in range(iterations):
    x = alg.run(x,y)
    y = func_loop(x)

# %%
np.max(alg.max_fitness_lst)
# Out:
# -0.07876806435811803

# %%
alg.best_solution()
# Out:
# array([0.418, 0.127, 0.049, 0.037, 0.185, 0.237, 0.084, 0.033, 0.024,
#        0.01 , 0.986])

# %%
np.sum(alg.best_solution())
# Out:
# 2.19

# %%
w0 = alg.best_solution()[0]
w1 = alg.best_solution()[1]
w2 = alg.best_solution()[2]
w3 = alg.best_solution()[3]
w4 = alg.best_solution()[4]
w5 = alg.best_solution()[5]
w6 = alg.best_solution()[6]
w7 = alg.best_solution()[7]
w8 = alg.best_solution()[8]
w9 = alg.best_solution()[9]
scale = alg.best_solution()[10]
# w0 = 0.1
# w2 = 0.0
# w3 = 0.027
# w4 = 0.162
# w5 = 0.156
# w6 = 0.153
model_avg = w0*model_0[:,1]*1000 + w1*model_1[:,1] + w2*model_2[:,1] + w3*model_3[:,1] + w4*model_4[:,1] + w5*model_5[:,1] + w6*model_6[:,1] + w7*model_7[:,1] + w8*model_8[:,1] + w9*model_9[:,1]

# %% [markdown]
# ## Plot Data

# %%
plt.rcParams.update({'font.size': 32})
plt.subplots(figsize=(8,8))
background = 2.5*10e4
plt.scatter(data[:,0], data[:,1]*((scale + 10e-10)*10e8) - background, label = 'Experimental Data', s = 20, color = 'red')
#plt.loglog(model3.x[10:], model3.y[10:]*5*10**-12, label = 'Model: Rectangular Prism with 7x7x5 nm', linewidth = 5, alpha = 0.75)
#plt.loglog(model2.x[50:-20], model2.y[50:-20]*2.55*10**-8, label = 'Model: Tube with Length 1000 nm', linewidth = 5, alpha = 0.75)
#plt.loglog(model.x[30:], model.y[30:]*1.55*10**-10, label = 'Model: Tube with 22.5 nm OD', linewidth = 5, alpha = 0.75)
# plt.loglog(model2[:,0], model2[:,1]*4*10**-8, label = 'Simulated Data', linewidth = 5, alpha = 0.75)
#plt.loglog(model_4[:,0], model_4[:,1]*4*10**-8, label = 'Simulated Data', linewidth = 5, alpha = 0.75)
# plt.loglog(model_0[:,0], model_0[:,1], label = '21', linewidth = 5, alpha = 0.75)
#plt.loglog(model1[:,0], model1[:,1], label = '21', linewidth = 5, alpha = 0.75)
#plt.loglog(model2[:,0], model2[:,1], label = '21', linewidth = 5, alpha = 0.75)
#plt.loglog(model3[:,0], model3[:,1], label = '21', linewidth = 5, alpha = 0.75)
# plt.loglog(model_4[:,0], model_4[:,1], label = '21', linewidth = 5, alpha = 0.75)
# plt.loglog(model_5[:,0], model_5[:,1], label = '21', linewidth = 5, alpha = 0.75)
# plt.loglog(model_6[:,0], model_6[:,1], label = '23', linewidth = 5, alpha = 0.75)
plt.loglog(model_1[:,0], model_avg, label = 'Model Best Fit', linewidth = 5, alpha = 1, color = 'k')
#
#plt.ylim([3*10**-2, 3*10**-1])
#plt.xlim([0.003, 0.2])
plt.legend(loc=1, prop={'size': 22})
plt.ylabel('Intensity (A.U.)')
plt.xlabel('q ($\AA^{-1}$)')
#plt.savefig('../Figures/Fitting/Best_Fit_RhuA_Assembly_2_largefont.jpg', dpi=600, bbox_inches="tight")
# Out:
# Text(0.5, 0, 'q ($\\AA^{-1}$)')

# %% [markdown]
# ## Note: Possible that a longer tube would improve the match at low-Q, Try to increase the diamteter of the tube also

# %%
alg.best_solution()
# Out:
# array([0.418, 0.127, 0.049, 0.037, 0.185, 0.237, 0.084, 0.033, 0.024,
#        0.01 , 0.986])

# %%
n_proteins = np.array([1, 196, 226, 256, 286, 316, 346, 376, 406, 436]).reshape(-1,1)
proportion_rhua_lst = []
for i in range(n_proteins.shape[0]):
    proportion_rhua = n_proteins[i][0]*alg.best_solution()[i]
    proportion_rhua_lst.append(proportion_rhua)
prop = np.array(proportion_rhua_lst)

# %%
prop[0] = prop[0]*1000

# %%
plt.subplots(figsize=(15,6))
plt.rcParams.update({'font.size': 12})
keys = ['Monomer','13-start', '15-start', '17-start','19-start','21-start','23-start', '25-start', '27-start','29-start']
plt.bar(keys, prop/np.sum(prop), width= 0.5)
plt.ylabel('Proportion of RhuA proteins as structure')
#plt.savefig('../Figures/Fitting/Histogram_RhuA_Assembly.jpg', dpi=500)
# Out:
# Text(0, 0.5, 'Proportion of RhuA proteins as structure')

# %%
plt.rcParams.update({'font.size': 36})
plt.subplots(figsize=(15,6))
plt.rcParams.update({'font.size': 12})
keys = ['1','13', '15', '17','19','21','23', '25', '27','29']
plt.bar(keys, prop/np.sum(prop), width= 0.5)
plt.ylabel('Frequency')
#plt.savefig('../Figures/Fitting/Histogram_RhuA_Assembly_large_font.jpg', dpi=500, bbox_inches="tight")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.subplots(figsize=(15,6))
plt.rcParams.update({'font.size': 12})
keys = ['13-start', '15-start', '17-start','19-start','21-start','23-start', '25-start', '27-start','29-start']
plt.bar(keys, prop[1:]/np.sum(prop[1:]), width= 0.5)
plt.ylabel('Proportion of RhuA proteins as structure')
#plt.savefig('../Figures/221112_Protein_Fits/Histogram_RhuA_Assembly.jpg')
# Out:
# Text(0, 0.5, 'Proportion of RhuA proteins as structure')

# %%
model = data[:,1]*((scale + 10e-10)*10e8) - background
sim_data = np.hstack((data[:,0].reshape(-1,1), model.reshape(-1,1)))

# %%
df = pd.DataFrame((prop/np.sum(prop)).reshape(-1,1), columns = ['proportion'])

# %%
#df.to_csv('../../SAXS/Merged_Data/2022/220817/Data/tubes_proportion.csv')
